# %%
from sqlalchemy import create_engine

# Tworzymy "silnik" wskazujący na naszą bazę w Dockerze
engine = create_engine('postgresql://user:password@localhost:5432/mydb')

# Próbujemy się połączyć
conn = engine.connect()
print("Połączono z bazą PostgreSQL!")
conn.close()
# Out:
# Połączono z bazą PostgreSQL!

# %%
from sqlalchemy import Column, Integer, String, Float, create_engine
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()
# Definicja prostego modelu
class Product(Base):
    __tablename__ = 'products'
    id = Column(Integer, primary_key=True, autoincrement=True)
    name = Column(String(200), nullable=False)
    category = Column(String(100))
    price = Column(Float, nullable=False)
    stock = Column(Integer, default=0)

    def __repr__(self):
        return f"<Product(id={self.id}, name='{self.name}', price={self.price})>"
# Tworzenie silnika (SQLite dla prostoty)
engine = create_engine('sqlite:///products.db', echo=False)
# Tworzenie wszystkich tabel zdefiniowanych w Base
Base.metadata.create_all(engine)
print("✅ Tabela 'products' została utworzona!")
# Sprawdzenie struktury
from sqlalchemy import inspect
inspector = inspect(engine)
print("Tabele w bazie:", inspector.get_table_names())
print("Kolumny w 'products':", [col['name'] for col in
inspector.get_columns('products')])
# Output: ['id', 'name', 'category', 'price', 'stock']
# Out:
# ✅ Tabela 'products' została utworzona!
# Tabele w bazie: ['products']
# Kolumny w 'products': ['id', 'name', 'category', 'price', 'stock']
# /var/folders/w7/4rpbx0_d3lsfbxxbc9b6t4fh0000gn/T/ipykernel_99322/3984630908.py:3: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()
